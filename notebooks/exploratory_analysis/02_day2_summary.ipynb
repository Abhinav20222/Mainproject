# %%
"""
DAY 2 SUMMARY: SMS Detection - Preprocessing & Feature Extraction
"""
print("="*60)
print("DAY 2 ACCOMPLISHMENTS")
print("="*60)

accomplishments = [
    "✓ Exploratory Data Analysis completed",
    "✓ SMS Preprocessing module created",
    "✓ Feature extraction with TF-IDF implemented",
    "✓ 520 features extracted per message",
    "✓ Comprehensive visualizations generated",
    "✓ All data saved for model training"
]

for item in accomplishments:
    print(item)

print("\n" + "="*60)
print("FILES CREATED")
print("="*60)

files = {
    "Preprocessing": "src/sms_detection/preprocessing.py",
    "Feature Extraction": "src/sms_detection/feature_extraction.py",
    "Visualization": "src/sms_detection/visualize_features.py",
    "Processed Data": "data/processed/sms_processed.csv",
    "Feature Matrix": "data/processed/sms_features.csv",
    "Feature Extractor": "data/models/feature_extractor.pkl"
}

for name, path in files.items():
    print(f"  • {name}: {path}")
# Out:
# ...
# DAY 2 ACCOMPLISHMENTS
# ...
# ✓ Exploratory Data Analysis completed
# ✓ SMS Preprocessing module created
# ✓ Feature extraction with TF-IDF implemented
# ✓ 520 features extracted per message
# ✓ Comprehensive visualizations generated
# ✓ All data saved for model training
#
# ...
# FILES CREATED
# ...
#   • Preprocessing: src/sms_detection/preprocessing.py
#   • Feature Extraction: src/sms_detection/feature_extraction.py
#   • Visualization: src/sms_detection/visualize_features.py
#   • Processed Data: data/processed/sms_processed.csv
#   • Feature Matrix: data/processed/sms_features.csv
#   • Feature Extractor: data/models/feature_extractor.pkl

# %%
import pandas as pd
from pathlib import Path

# Load processed data
processed_df = pd.read_csv('../../data/processed/sms_processed.csv')
features_df = pd.read_csv('../../data/processed/sms_features.csv')

print("PROCESSED DATA")
print("-"*60)
print(f"Shape: {processed_df.shape}")
print(f"Columns: {list(processed_df.columns)[:10]}...")

print("\nFEATURE MATRIX")
print("-"*60)
print(f"Shape: {features_df.shape}")
print(f"Total features: {features_df.shape[1] - 1}  # excluding label")

print("\nREADY FOR MODEL TRAINING!")
# Out:
# PROCESSED DATA
# ------------------------------------------------------------
# Shape: (5572, 25)
# Columns: ['label', 'message', 'cleaned_text', 'processed_text', 'message_length', 'word_count', 'char_count', 'avg_word_length', 'special_char_count', 'digit_count']...
#
# FEATURE MATRIX
# ------------------------------------------------------------
# Shape: (5572, 520)
# Total features: 519  # excluding label
#
# READY FOR MODEL TRAINING!
